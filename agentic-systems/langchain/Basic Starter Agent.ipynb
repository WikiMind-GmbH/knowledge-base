# %% [markdown]
# # Quick Starter Agent

# %%
# !pip install -qU langchain deepagents

# %%
# Saved api keys are in a .env file
from dotenv import load_dotenv
from pathlib import Path

# Check current directory and up to two parent directories for .env
for path in [Path.cwd(), Path.cwd().parent, Path.cwd().parent.parent]:
    dotenv_file = path / ".env"
    if dotenv_file.exists():
        load_dotenv(dotenv_file)
        break

# %% [markdown]
# ## Build a basic agent
#
# Start by creating a simple agent that can answer questions and call tools. The agent in this example uses the chosen language model, a basic weather function as a tool, and a simple prompt to guide its behavior:

# %%
from langchain.agents import create_agent

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

agent = create_agent(
    model="openai:gpt-5.4-mini",
    tools=[get_weather],
    system_prompt="You are a helpful assistant",
)

result = agent.invoke(
    {"messages": [{"role": "user", "content": "What's the weather in San Francisco?"}]}
)
print(result["messages"][-1].content_blocks)
# Out:
# [{'type': 'text', 'text': 'It’s always sunny in San Francisco!'}]

# %% [markdown]
# When you run the code and prompt the agent to tell you about the weather in San Francisco, the agent uses that input and its available context. The agent understands that you are asking about the weather for the city San Francisco and therefore calls the weather tool with the provided city name.

# %% [markdown]
# As we can see langchain (similar to other packages) provides a high level abstraction for creating and running an agent. Of course the tool here is a toy version but the power is that we can define a function in python which then becomes a tool for the agent. And since python allows us to write very versatile functions, we can do a lot!
